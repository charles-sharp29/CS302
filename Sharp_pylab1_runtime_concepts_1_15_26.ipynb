# %% [markdown]
# <a href="https://colab.research.google.com/github/charles-sharp29/CS302/blob/main/Sharp_pylab1_runtime_concepts_1_15_26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
File: Sharp_pylab1_runtime-concepts_1-15-26.ipynb
Date: 1/15/2026
Author: Charles Sharp
Purpose: Lab practicing runtime concepts
"""
# Out:
# '\nFile: Sharp_pylab1_runtime-concepts_1-15-26.ipynb\nDate: 1/15/2026\nAuthor: Charles Sharp\nPurpose: Lab practicing runtime concepts\n'

# %%
a = 10
b = a
a = 20
print(b)
# Out:
# 11654664
# 11654664
# 10

# %% [markdown]
# Was the object mutable or immutable?
# - The objects are immutable because they are integers and cannot be changed
#
# Did Python mutate the object or rebind the name?
# - Python rebinded the name because the object changed while keeping the same name

# %%
def f(x):
  x = x + 1
  print(x)

n = 5
f(n)
print(n)
# Out:
# 6
# 5

# %% [markdown]
# Was the object mutable or immutable?
# - The objects are immutable because they are integers and cannot be changed
#
# Did Python mutate the object or rebind the name?
# - Python rebinded the name locally in the function but did not change the object outside the function

# %%
x = 5
print(id(x))
x += 1
print(id(x))
# Out:
# 11654504
# 11654536

# %% [markdown]
# Was the object mutable or immutable?
# - The object is immutable because it is an integer and cannot be changed
#
# Did Python mutate the object or rebind the name?
# - Python rebinded the name because the object changed while keeping the same name

# %%
lst = [1,2]
print(id(lst))
lst.append(3)
print(id(lst))
# Out:
# 132384115811520
# 132384115811520

# %% [markdown]
# Was the object mutable or immutable?
# - The object is mutable because it is a list and can be changed
#
# Did Python mutate the object or rebind the name?
# - Python mutated the object becasue the objects value changed while the name stayed the same

# %%
def change(x):
  x = x + 10

a = 5
change(a)
print(a)
# Out:
# 5

# %% [markdown]
# Was the object mutable or immutable?
# - The objects are immutable because they are integers and cannot be changed
#
# Did Python mutate the object or rebind the name?
# - Python rebinded the name in the function but the object was not rebinded outside the function

# %%
def change(lst):
  lst.append(99)

data = [1,2]
change(data)
print(data)
# Out:
# [1, 2, 99]

# %% [markdown]
# Was the object mutable or immutable?
# - The object mutable because it is a list and can be changed
#
# Did Python mutate the object or rebind the name?
# - Python mutated the object because it added a number to the list

# %%
def reset_wrong(lst):
  lst = []

def reset_right(lst):
  lst.clear()

data = [1,2,3]
reset_wrong(data)
print(data)

reset_right(data)
print(data)
# Out:
# [1, 2, 3]
# []

# %% [markdown]
# Was the object mutable or immutable?
# - The object is mutable because it is a list and can be changed
#
# Did Python mutate the object or rebind the name?
# - Python rebinded the name in the reset_wrong function because the name changed and mutated the object in the reset_right function

# %%
def demo(x):
  print(id(x))
  x.append(5)
  print(id(x))

lst = [1,2]
print(id(lst))
demo(lst)
# Out:
# 132384114766080
# 132384114766080
# 132384114766080

# %% [markdown]
# Was the object mutable or immutable?
# - The object is mutable because it is a list and can be changed
#
# Did Python mutate the object or rebind the name?
# - Python mutated the oject because it added a 5 to the list

# %%
a = [1,2]
b = [1,2]

print(a == b)
print(a is b)
# Out:
# True
# False

# %% [markdown]
# Was the object mutable or immutable?
# - The objects are mutable because they are both lists which can be changed
#
# Did Python mutate the object or rebind the name?
# - Neither because Python just compared the values but didn't change anything

# %%
x = [1,2]
x = [3,4]

# %% [markdown]
# Was the object mutable or immutable?
# - The objects are mutable because they are both lists which can be changed
#
# Did Python mutate the object or rebind the name?
# - Python rebinded the name because the name stays the same while the object it calls changes
